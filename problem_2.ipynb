# %% [markdown]
# <a href="https://colab.research.google.com/github/sonetemon/Computer-Vision/blob/main/problem_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('/content/1.jpg')
plt.figure(figsize=[12,6])
plt.subplot(1,2,1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
# Out:
# (-0.5, 511.5, 255.5, -0.5)

# %%
from PIL import Image
def split_image(image):
    image = np.array(image)
    cityscape, label = image[:, :256, :], image[:, 256:, :]
    return cityscape, label

sample_image = np.array(image)
cityscape, label = split_image(image)
cityscape, label = Image.fromarray(cityscape), Image.fromarray(label)
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(cityscape)
axes[1].imshow(label)

# %%
# Improve the image quality by applying brightness and contrast enhancement techniques
cityscape = np.array(cityscape)
alpha = 1.5
beta = 20

# Apply brightness and contrast adjustment
enhanced_image = cv2.convertScaleAbs(cityscape, alpha=alpha, beta=beta)
plt.figure(figsize=[12,6])
#plt.subplot(1,2,1)
plt.imshow(enhanced_image)
plt.title('Improved Image Quality')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
#Task 3: Detect edges to analyze facial structures and expressions

# Convert image to grayscale
gray_image = cv2.cvtColor(enhanced_image, cv2.COLOR_BGR2GRAY)

# Apply Canny edge detection
edges = cv2.Canny(gray_image, 100, 200)
plt.figure(figsize=[12,6])
#plt.subplot(1,2,1)
plt.imshow(edges)
plt.title('Edge Detection')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
#Task 4: Use image blurring to soften non-essential features while keeping the focus on facial expressions.
# Apply Gaussian blur
blurred_image = cv2.GaussianBlur(enhanced_image, (15, 15), 0)
plt.figure(figsize=[12,6])
#plt.subplot(1,2,1)
plt.imshow(blurred_image)
plt.title('Image blurring')
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)
